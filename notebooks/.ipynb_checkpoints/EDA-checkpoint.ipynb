# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max.columns', None)
pd.set_option('display.max_colwidth', None)
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')
dftrain = pd.read_csv("../data/train.csv")
dftrain.set_index('Store',inplace=True)
dfstore = pd.read_csv("../data/store.csv")
dfstore.set_index('Store',inplace=True)
dftrain.head()
# Out:
#        DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# Store
# 1              5  2015-07-31   5263        555     1      1            0
# 2              5  2015-07-31   6064        625     1      1            0
# 3              5  2015-07-31   8314        821     1      1            0
# 4              5  2015-07-31  13995       1498     1      1            0
# 5              5  2015-07-31   4822        559     1      1            0
#
#        SchoolHoliday
# Store
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# 5                  1

# %%
dfstore.head()
# Out:
#       StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# Store
# 1             c          a               1270.0                        9.0
# 2             a          a                570.0                       11.0
# 3             a          a              14130.0                       12.0
# 4             c          c                620.0                        9.0
# 5             a          a              29910.0                        4.0
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# Store
# 1                        2008.0       0              NaN              NaN
# 2                        2007.0       1             13.0           2010.0
# 3                        2006.0       1             14.0           2011.0
# 4                        2009.0       0              NaN              NaN
# 5                        2015.0       0              NaN              NaN
#
#          PromoInterval
# Store
# 1                  NaN
# 2      Jan,Apr,Jul,Oct
# 3      Jan,Apr,Jul,Oct
# 4                  NaN
# 5                  NaN

# %%
#merge train and store data
df = pd.merge(dftrain,dfstore,how='inner',on='Store')
df.sample(10)
# Out:
#        DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# Store
# 814            2  2013-06-11   5954        550     1      0            0
# 927            6  2014-10-25   4288        651     1      0            0
# 757            6  2014-09-20   4843        464     1      0            0
# 18             4  2015-06-04   7727        764     1      1            0
# 93             7  2013-12-08      0          0     0      0            0
# 967            7  2013-05-05      0          0     0      0            0
# 895            4  2015-03-05  10265        884     1      1            0
# 411            4  2013-08-22   7085        623     1      0            0
# 101            5  2013-06-28   6771        695     1      0            0
# 569            6  2014-04-19   2616        377     1      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# Store
# 814                0         d          c              24530.0
# 927                0         a          a                480.0
# 757                0         a          c               3450.0
# 18                 0         d          c              13840.0
# 93                 0         a          a              16690.0
# 967                0         a          c               3560.0
# 895                0         a          c               4150.0
# 411                0         d          c               8460.0
# 101                1         d          c               2440.0
# 569                0         a          a               1340.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# Store
# 814                          7.0                    2013.0       0
# 927                          NaN                       NaN       0
# 757                          NaN                       NaN       0
# 18                           6.0                    2010.0       1
# 93                           NaN                       NaN       1
# 967                          9.0                    2013.0       1
# 895                          NaN                       NaN       0
# 411                          NaN                       NaN       0
# 101                          NaN                       NaN       1
# 569                          9.0                    2006.0       0
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# Store
# 814                NaN              NaN               NaN
# 927                NaN              NaN               NaN
# 757                NaN              NaN               NaN
# 18                14.0           2012.0   Jan,Apr,Jul,Oct
# 93                14.0           2011.0   Jan,Apr,Jul,Oct
# 967               36.0           2013.0   Jan,Apr,Jul,Oct
# 895                NaN              NaN               NaN
# 411                NaN              NaN               NaN
# 101               22.0           2012.0  Mar,Jun,Sept,Dec
# 569                NaN              NaN               NaN

# %%
dftrain.shape
# Out:
# (1017209, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 1 to 1115
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   DayOfWeek                  1017209 non-null  int64
#  1   Date                       1017209 non-null  object
#  2   Sales                      1017209 non-null  int64
#  3   Customers                  1017209 non-null  int64
#  4   Open                       1017209 non-null  int64
#  5   Promo                      1017209 non-null  int64
#  6   StateHoliday               1017209 non-null  object
#  7   SchoolHoliday              1017209 non-null  int64
#  8   StoreType                  1017209 non-null  object
#  9   Assortment                 1017209 non-null  object
#  10  CompetitionDistance        1014567 non-null  float64
#  11  CompetitionOpenSinceMonth  693861 non-null   float64
#  12  CompetitionOpenSinceYear   693861 non-null   float64
#  13  Promo2                     1017209 non-null  int64
#  14  Promo2SinceWeek            509178 non-null   float64
#  15  Promo2SinceYear            509178 non-null   float64
#  16  PromoInterval              509178 non-null   object
# dtypes: float64(5), int64(7), object(5)
# memory usage: 139.7+ MB

# %%
#Var_Corr = df.corr()
#sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)

corr = df.corr()

plt.figure(figsize = (10, 10))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.show()
