# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max.columns', None)
pd.set_option('display.max_colwidth', None)
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')
train = pd.read_csv("../data/train.csv")
store = pd.read_csv("../data/store.csv")
test = pd.read_csv("../data/test.csv")
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store.fillna(0, inplace=True)

# %%
# draw store 1 and store 10 sales distribution plot
import matplotlib.pyplot as plt
store_1 = train.loc[(train["Store"]==1)&(train['Sales']>0), ['Date',"Sales"]]
store_10 = train.loc[(train["Store"]==10)&(train['Sales']>0), ['Date',"Sales"]]
f = plt.figure(figsize=(18,10))
ax1 = f.add_subplot(211)
ax1.plot(store_1['Date'], store_1['Sales'], '-')
ax1.set_xlabel('Time')
ax1.set_ylabel('Sales')
ax1.set_title('Store 1 Sales Distribution')

ax2 = f.add_subplot(212)
ax2.plot(store_10['Date'], store_10['Sales'], '-')
ax2.set_xlabel('Time')
ax2.set_ylabel('Sales')
ax2.set_title('Store 10 Sales Distribution')
# Out:
# Text(0.5, 1.0, 'Store 10 Sales Distribution')

# %%
# check missing values in test open column
test[test.Open.isnull()]
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 479      480    622          4  2015-09-17   NaN      1            0
# 1335    1336    622          3  2015-09-16   NaN      1            0
# 2191    2192    622          2  2015-09-15   NaN      1            0
# 3047    3048    622          1  2015-09-14   NaN      1            0
# 4759    4760    622          6  2015-09-12   NaN      0            0
# 5615    5616    622          5  2015-09-11   NaN      0            0
# 6471    6472    622          4  2015-09-10   NaN      0            0
# 7327    7328    622          3  2015-09-09   NaN      0            0
# 8183    8184    622          2  2015-09-08   NaN      0            0
# 9039    9040    622          1  2015-09-07   NaN      0            0
# 10751  10752    622          6  2015-09-05   NaN      0            0
#
#        SchoolHoliday
# 479                0
# 1335               0
# 2191               0
# 3047               0
# 4759               0
# 5615               0
# 6471               0
# 7327               0
# 8183               0
# 9039               0
# 10751              0

# %%
# fill missing values in test with 1
test.fillna(value = 1, inplace = True)

# %%
# merge data with store 
train = pd.merge(train, store, on='Store')
test = pd.merge(test, store, on='Store')

# split the last 6 weeks data as hold-out set (idea from Gert https://www.kaggle.com/c/rossmann-store-sales/discussion/18024)
train = train.sort_values(['Date'],ascending = False)
train_total = train.copy()

split_index = 6*7*1115
valid = train[:split_index] 
train = train[split_index:]

# only use data of Sales>0 and Open is 1
valid = valid[(valid.Open != 0)&(valid.Sales >0)]
train = train[(train.Open != 0)&(train.Sales >0)]
train_total = train_total[(train_total.Open != 0)&(train_total.Sales >0)]

# %%
# check distribution of sales in train set
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
g1 = sns.distplot(train['Sales'],hist = True,label='skewness:{:.2f}'.format(train['Sales'].skew()),ax = ax1)
g1.legend()
g1.set(xlabel = 'Sales', ylabel = 'Density', title = 'Sales Distribution')
g2 = sns.distplot(np.log1p(train['Sales']),hist = True,label='skewness:{:.2f}'.format(np.log1p(train['Sales']).skew()),ax=ax2)
g2.legend()
g2.set(xlabel = 'log(Sales+1)',ylabel = 'Density', title = 'log(Sales+1) Distribution')
plt.show()

# %%
# process train and test
def process(data, isTest = False):
    # label encode some features
    mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
    data.StoreType.replace(mappings, inplace=True)
    data.Assortment.replace(mappings, inplace=True)
    data.StateHoliday.replace(mappings, inplace=True)
    
    # extract some features from date column  
    data['Month'] = data.Date.dt.month
    data['Year'] = data.Date.dt.year
    data['Day'] = data.Date.dt.day
    data['WeekOfYear'] = data.Date.dt.weekofyear
    
    # calculate competiter open time in months
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
        (data.Month - data.CompetitionOpenSinceMonth)
    data['CompetitionOpen'] = data['CompetitionOpen'].apply(lambda x: x if x > 0 else 0)
    
    # calculate promo2 open time in months
    data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0
    data['PromoOpen'] = data['PromoOpen'].apply(lambda x: x if x > 0 else 0)
                                                 
    # Indicate whether the month is in promo interval
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', \
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['month_str'] = data.Month.map(month2str)

    def check(row):
        if isinstance(row['PromoInterval'],str) and row['month_str'] in row['PromoInterval']:
            return 1
        else:
            return 0
        
    data['IsPromoMonth'] =  data.apply(lambda row: check(row),axis=1)    
    
    # select the features we need
    features = ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday',
       'StoreType', 'Assortment', 'CompetitionDistance',
       'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
       'Promo2SinceWeek', 'Promo2SinceYear', 'Year', 'Month', 'Day',
       'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth']  
    if not isTest:
        features.append('Sales')
        
    data = data[features]
    return data
train["Date"]=pd.to_datetime(train["Date"])
test["Date"]=pd.to_datetime(test["Date"])
valid["Date"]=pd.to_datetime(valid["Date"])
train_total["Date"]=pd.to_datetime(train_total["Date"])
train = process(train)
valid = process(valid)
train_total = process(train_total)
x_test = process(test,isTest = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804056 entries, 284584 to 238339
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      804056 non-null  int64
#  1   DayOfWeek                  804056 non-null  int64
#  2   Promo                      804056 non-null  int64
#  3   StateHoliday               804056 non-null  int64
#  4   SchoolHoliday              804056 non-null  int64
#  5   StoreType                  804056 non-null  int64
#  6   Assortment                 804056 non-null  int64
#  7   CompetitionDistance        804056 non-null  float64
#  8   CompetitionOpenSinceMonth  804056 non-null  float64
#  9   CompetitionOpenSinceYear   804056 non-null  float64
#  10  Promo2                     804056 non-null  int64
#  11  Promo2SinceWeek            804056 non-null  float64
#  12  Promo2SinceYear            804056 non-null  float64
#  13  Year                       804056 non-null  int64
#  14  Month                      804056 non-null  int64
#  15  Day                        804056 non-null  int64
#  16  WeekOfYear                 804056 non-null  int64
#  17  CompetitionOpen            804056 non-null  float64
#  18  PromoOpen                  804056 non-null  float64
#  19  IsPromoMonth               804056 non-null  int64
#  20  Sales                      804056 non-null  int64
# dtypes: float64(7), int64(14)
# memory usage: 135.0 MB

# %%
# sort by index
valid.sort_index(inplace = True)
train.sort_index(inplace = True)
train_total.sort_index(inplace = True)

# split x and y
x_train, y_train = train.drop(columns = ['Sales']), np.log1p(train['Sales'])
x_valid, y_valid = valid.drop(columns = ['Sales']), np.log1p(valid['Sales'])
x_train_total, y_train_total = train_total.drop(columns = ['Sales']), np.log1p(train_total['Sales'])

# %%
# define eval metrics
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(n_estimators = 15)
clf.fit(x_train, y_train)
# validation
y_pred = clf.predict(x_valid)
error = rmspe(np.expm1(y_valid), np.expm1(y_pred))
print('RMSPE: {:.4f}'.format(error))
# Out:
# RMSPE: 0.1606

# %%
# plot feature importance for random forest model, show top 10 features
feat_importances = pd.Series(clf.feature_importances_, index=x_train.columns)
feat_importances.nlargest(10).sort_values(ascending = True).plot(kind='barh')
plt.xlabel('importance')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
import xgboost as xgb

params = {"objective": "reg:linear", # for linear regression
          "booster" : "gbtree",   # use tree based models 
          "eta": 0.03,   # learning rate
          "max_depth": 10,    # maximum depth of a tree
          "subsample": 0.9,    # Subsample ratio of the training instances
          "colsample_bytree": 0.7,   # Subsample ratio of columns when constructing each tree
          "silent": 1,   # silent mode
          "seed": 10   # Random number seed
          }
num_boost_round = 500

dtrain = xgb.DMatrix(x_train, y_train)
dvalid = xgb.DMatrix(x_valid, y_valid)
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
# train the xgboost model
model = xgb.train(params, dtrain, num_boost_round, evals=watchlist, \
  early_stopping_rounds= 100, feval=rmspe_xg, verbose_eval=True)
# Out:
# [19:01:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:8.02087	train-rmspe:0.99981	eval-rmse:8.02744	eval-rmspe:0.99981
# [1]	train-rmse:7.78075	train-rmspe:0.99971	eval-rmse:7.78738	eval-rmspe:0.99971
# [2]	train-rmse:7.54784	train-rmspe:0.99959	eval-rmse:7.55454	eval-rmspe:0.99960
# [3]	train-rmse:7.32197	train-rmspe:0.99944	eval-rmse:7.32858	eval-rmspe:0.99945
# [4]	train-rmse:7.10287	train-rmspe:0.99926	eval-rmse:7.10855	eval-rmspe:0.99927
# [5]	train-rmse:6.89031	train-rmspe:0.99905	eval-rmse:6.89636	eval-rmspe:0.99906
# [6]	train-rmse:6.68408	train-rmspe:0.99880	eval-rmse:6.69055	eval-rmspe:0.99881
# [7]	train-rmse:6.48406	train-rmspe:0.99850	eval-rmse:6.49084	eval-rmspe:0.99851
# [8]	train-rmse:6.29010	train-rmspe:0.99814	eval-rmse:6.29697	eval-rmspe:0.99816
# [9]	train-rmse:6.10199	train-rmspe:0.99772	eval-rmse:6.10848	eval-rmspe:0.99775
# [10]	train-rmse:5.91955	train-rmspe:0.99724	eval-rmse:5.92563	eval-rmspe:0.99726
# [11]	train-rmse:5.74251	train-rmspe:0.99667	eval-rmse:5.74879	eval-rmspe:0.99671
# [12]	train-rmse:5.57088	train-rmspe:0.99602	eval-rmse:5.57667	eval-rmspe:0.99606
# [13]	train-rmse:5.40442	train-rmspe:0.99527	eval-rmse:5.40974	eval-rmspe:0.99532
# [14]	train-rmse:5.24286	train-rmspe:0.99442	eval-rmse:5.24853	eval-rmspe:0.99447
# [15]	train-rmse:5.08626	train-rmspe:0.99345	eval-rmse:5.09160	eval-rmspe:0.99351
# [16]	train-rmse:4.93431	train-rmspe:0.99235	eval-rmse:4.93986	eval-rmspe:0.99243
# [17]	train-rmse:4.78694	train-rmspe:0.99112	eval-rmse:4.79240	eval-rmspe:0.99121
# [18]	train-rmse:4.64397	train-rmspe:0.98974	eval-rmse:4.64982	eval-rmspe:0.98984
# [19]	train-rmse:4.50530	train-rmspe:0.98820	eval-rmse:4.51139	eval-rmspe:0.98832
# [20]	train-rmse:4.37079	train-rmspe:0.98650	eval-rmse:4.37602	eval-rmspe:0.98662
# [21]	train-rmse:4.24032	train-rmspe:0.98461	eval-rmse:4.24605	eval-rmspe:0.98476
# [22]	train-rmse:4.11378	train-rmspe:0.98253	eval-rmse:4.11963	eval-rmspe:0.98270
# [23]	train-rmse:3.99106	train-rmspe:0.98024	eval-rmse:3.99609	eval-rmspe:0.98042
# [24]	train-rmse:3.87206	train-rmspe:0.97774	eval-rmse:3.87669	eval-rmspe:0.97793
# [25]	train-rmse:3.75663	train-rmspe:0.97502	eval-rmse:3.76149	eval-rmspe:0.97523
# [26]	train-rmse:3.64469	train-rmspe:0.97206	eval-rmse:3.64939	eval-rmspe:0.97229
# [27]	train-rmse:3.53610	train-rmspe:0.96886	eval-rmse:3.54087	eval-rmspe:0.96912
# [28]	train-rmse:3.43085	train-rmspe:0.96541	eval-rmse:3.43531	eval-rmspe:0.96568
# [29]	train-rmse:3.32880	train-rmspe:0.96169	eval-rmse:3.33298	eval-rmspe:0.96197
# [30]	train-rmse:3.22977	train-rmspe:0.95771	eval-rmse:3.23398	eval-rmspe:0.95802
# [31]	train-rmse:3.13380	train-rmspe:0.95345	eval-rmse:3.13767	eval-rmspe:0.95377
# [32]	train-rmse:3.04066	train-rmspe:0.94893	eval-rmse:3.04426	eval-rmspe:0.94926
# [33]	train-rmse:2.95034	train-rmspe:0.94412	eval-rmse:2.95407	eval-rmspe:0.94449
# [34]	train-rmse:2.86275	train-rmspe:0.93903	eval-rmse:2.86644	eval-rmspe:0.93942
# [35]	train-rmse:2.77778	train-rmspe:0.93366	eval-rmse:2.78146	eval-rmspe:0.93407
# [36]	train-rmse:2.69538	train-rmspe:0.92800	eval-rmse:2.69847	eval-rmspe:0.92840
# [37]	train-rmse:2.61550	train-rmspe:0.92205	eval-rmse:2.61794	eval-rmspe:0.92241
# [38]	train-rmse:2.53803	train-rmspe:0.91581	eval-rmse:2.54068	eval-rmspe:0.91622
# [39]	train-rmse:2.46290	train-rmspe:0.90929	eval-rmse:2.46556	eval-rmspe:0.90972
# [40]	train-rmse:2.39012	train-rmspe:0.90247	eval-rmse:2.39172	eval-rmspe:0.90280
# [41]	train-rmse:2.31953	train-rmspe:0.89537	eval-rmse:2.32029	eval-rmspe:0.89561
# [42]	train-rmse:2.25095	train-rmspe:0.88803	eval-rmse:2.25177	eval-rmspe:0.88827
# [43]	train-rmse:2.18451	train-rmspe:0.88040	eval-rmse:2.18478	eval-rmspe:0.88057
# [44]	train-rmse:2.12014	train-rmspe:0.87251	eval-rmse:2.11992	eval-rmspe:0.87259
# [45]	train-rmse:2.05773	train-rmspe:0.86437	eval-rmse:2.05753	eval-rmspe:0.86444
# [46]	train-rmse:1.99710	train-rmspe:0.85601	eval-rmse:1.99686	eval-rmspe:0.85604
# [47]	train-rmse:1.93833	train-rmspe:0.84740	eval-rmse:1.93802	eval-rmspe:0.84740
# [48]	train-rmse:1.88146	train-rmspe:0.83855	eval-rmse:1.88036	eval-rmspe:0.83837
# [49]	train-rmse:1.82635	train-rmspe:0.82947	eval-rmse:1.82443	eval-rmspe:0.82907
# [50]	train-rmse:1.77282	train-rmspe:0.82021	eval-rmse:1.77085	eval-rmspe:0.81976
# [51]	train-rmse:1.72095	train-rmspe:0.81076	eval-rmse:1.71901	eval-rmspe:0.81025
# [52]	train-rmse:1.67061	train-rmspe:0.80114	eval-rmse:1.66876	eval-rmspe:0.80058
# [53]	train-rmse:1.62186	train-rmspe:0.79133	eval-rmse:1.61997	eval-rmspe:0.79071
# [54]	train-rmse:1.57448	train-rmspe:0.78141	eval-rmse:1.57264	eval-rmspe:0.78072
# [55]	train-rmse:1.52861	train-rmspe:0.77133	eval-rmse:1.52676	eval-rmspe:0.77056
# [56]	train-rmse:1.48394	train-rmspe:0.76117	eval-rmse:1.48204	eval-rmspe:0.76027
# [57]	train-rmse:1.44090	train-rmspe:0.75082	eval-rmse:1.43891	eval-rmspe:0.74980
# [58]	train-rmse:1.39915	train-rmspe:0.74038	eval-rmse:1.39686	eval-rmspe:0.73917
# [59]	train-rmse:1.35878	train-rmspe:0.72984	eval-rmse:1.35487	eval-rmspe:0.72803
# [60]	train-rmse:1.31960	train-rmspe:0.71923	eval-rmse:1.31541	eval-rmspe:0.71720
# [61]	train-rmse:1.28166	train-rmspe:0.70857	eval-rmse:1.27748	eval-rmspe:0.70636
# [62]	train-rmse:1.24491	train-rmspe:0.69784	eval-rmse:1.24027	eval-rmspe:0.69534
# [63]	train-rmse:1.20935	train-rmspe:0.68709	eval-rmse:1.20329	eval-rmspe:0.68391
# [64]	train-rmse:1.17467	train-rmspe:0.67636	eval-rmse:1.16842	eval-rmspe:0.67293
# [65]	train-rmse:1.14118	train-rmspe:0.66559	eval-rmse:1.13472	eval-rmspe:0.66188
# [66]	train-rmse:1.10873	train-rmspe:0.65484	eval-rmse:1.10216	eval-rmspe:0.65086
# [67]	train-rmse:1.07732	train-rmspe:0.64408	eval-rmse:1.06991	eval-rmspe:0.63954
# [68]	train-rmse:1.04690	train-rmspe:0.63338	eval-rmse:1.03928	eval-rmspe:0.62850
# [69]	train-rmse:1.01751	train-rmspe:0.62272	eval-rmse:1.00944	eval-rmspe:0.61737
# [70]	train-rmse:0.98898	train-rmspe:0.61214	eval-rmse:0.98101	eval-rmspe:0.60650
# [71]	train-rmse:0.96109	train-rmspe:0.60163	eval-rmse:0.95317	eval-rmspe:0.59571
# [72]	train-rmse:0.93439	train-rmspe:0.59116	eval-rmse:0.92685	eval-rmspe:0.58511
# [73]	train-rmse:0.90854	train-rmspe:0.58080	eval-rmse:0.90126	eval-rmspe:0.57454
# [74]	train-rmse:0.88343	train-rmspe:0.57053	eval-rmse:0.87601	eval-rmspe:0.56386
# [75]	train-rmse:0.85926	train-rmspe:0.56033	eval-rmse:0.85194	eval-rmspe:0.55339
# [76]	train-rmse:0.83583	train-rmspe:0.55029	eval-rmse:0.82824	eval-rmspe:0.54287
# [77]	train-rmse:0.81320	train-rmspe:0.54033	eval-rmse:0.80545	eval-rmspe:0.53251
# [78]	train-rmse:0.79128	train-rmspe:0.53058	eval-rmse:0.78349	eval-rmspe:0.52235
# [79]	train-rmse:0.77011	train-rmspe:0.52090	eval-rmse:0.76277	eval-rmspe:0.51256
# [80]	train-rmse:0.74942	train-rmspe:0.51141	eval-rmse:0.74200	eval-rmspe:0.50263
# [81]	train-rmse:0.72951	train-rmspe:0.50209	eval-rmse:0.72190	eval-rmspe:0.49280
# [82]	train-rmse:0.71026	train-rmspe:0.49295	eval-rmse:0.70264	eval-rmspe:0.48325
# [83]	train-rmse:0.69170	train-rmspe:0.48396	eval-rmse:0.68388	eval-rmspe:0.47375
# [84]	train-rmse:0.67371	train-rmspe:0.47515	eval-rmse:0.66512	eval-rmspe:0.46409
# [85]	train-rmse:0.65638	train-rmspe:0.46657	eval-rmse:0.64744	eval-rmspe:0.45483
# [86]	train-rmse:0.63953	train-rmspe:0.45812	eval-rmse:0.63084	eval-rmspe:0.44604
# [87]	train-rmse:0.62324	train-rmspe:0.44988	eval-rmse:0.61469	eval-rmspe:0.43737
# [88]	train-rmse:0.60748	train-rmspe:0.44185	eval-rmse:0.59886	eval-rmspe:0.42883
# [89]	train-rmse:0.59240	train-rmspe:0.43404	eval-rmse:0.58397	eval-rmspe:0.42064
# [90]	train-rmse:0.57739	train-rmspe:0.42627	eval-rmse:0.56902	eval-rmspe:0.41240
# [91]	train-rmse:0.56306	train-rmspe:0.41865	eval-rmse:0.55465	eval-rmspe:0.40438
# [92]	train-rmse:0.54949	train-rmspe:0.41142	eval-rmse:0.54087	eval-rmspe:0.39659
# [93]	train-rmse:0.53636	train-rmspe:0.40443	eval-rmse:0.52807	eval-rmspe:0.38927
# [94]	train-rmse:0.52376	train-rmspe:0.39766	eval-rmse:0.51550	eval-rmspe:0.38203
# [95]	train-rmse:0.51134	train-rmspe:0.39099	eval-rmse:0.50325	eval-rmspe:0.37498
# [96]	train-rmse:0.49949	train-rmspe:0.38460	eval-rmse:0.49120	eval-rmspe:0.36794
# [97]	train-rmse:0.48790	train-rmspe:0.37843	eval-rmse:0.47965	eval-rmspe:0.36122
# [98]	train-rmse:0.47692	train-rmspe:0.37244	eval-rmse:0.46906	eval-rmspe:0.35497
# [99]	train-rmse:0.46641	train-rmspe:0.36673	eval-rmse:0.45876	eval-rmspe:0.34887
# [100]	train-rmse:0.45632	train-rmspe:0.36125	eval-rmse:0.44891	eval-rmspe:0.34303
# [101]	train-rmse:0.44645	train-rmspe:0.35587	eval-rmse:0.43944	eval-rmspe:0.33741
# [102]	train-rmse:0.43709	train-rmspe:0.35081	eval-rmse:0.43013	eval-rmspe:0.33186
# [103]	train-rmse:0.42771	train-rmspe:0.34572	eval-rmse:0.42065	eval-rmspe:0.32621
# [104]	train-rmse:0.41857	train-rmspe:0.34083	eval-rmse:0.41175	eval-rmspe:0.32088
# [105]	train-rmse:0.41027	train-rmspe:0.33637	eval-rmse:0.40362	eval-rmspe:0.31604
# [106]	train-rmse:0.40225	train-rmspe:0.33207	eval-rmse:0.39600	eval-rmspe:0.31153
# [107]	train-rmse:0.39426	train-rmspe:0.32788	eval-rmse:0.38809	eval-rmspe:0.30683
# [108]	train-rmse:0.38637	train-rmspe:0.32368	eval-rmse:0.38034	eval-rmspe:0.30224
# [109]	train-rmse:0.37907	train-rmspe:0.31983	eval-rmse:0.37327	eval-rmspe:0.29807
# [110]	train-rmse:0.37210	train-rmspe:0.31620	eval-rmse:0.36679	eval-rmspe:0.29429
# [111]	train-rmse:0.36526	train-rmspe:0.31270	eval-rmse:0.36012	eval-rmspe:0.29036
# [112]	train-rmse:0.35887	train-rmspe:0.30952	eval-rmse:0.35388	eval-rmspe:0.28677
# [113]	train-rmse:0.35280	train-rmspe:0.30643	eval-rmse:0.34811	eval-rmspe:0.28347
# [114]	train-rmse:0.34664	train-rmspe:0.30338	eval-rmse:0.34217	eval-rmspe:0.28010
# [115]	train-rmse:0.34026	train-rmspe:0.30013	eval-rmse:0.33585	eval-rmspe:0.27636
# [116]	train-rmse:0.33482	train-rmspe:0.29752	eval-rmse:0.33057	eval-rmspe:0.27344
# [117]	train-rmse:0.32932	train-rmspe:0.29474	eval-rmse:0.32536	eval-rmspe:0.27044
# [118]	train-rmse:0.32448	train-rmspe:0.29251	eval-rmse:0.32098	eval-rmspe:0.26810
# [119]	train-rmse:0.31972	train-rmspe:0.29034	eval-rmse:0.31655	eval-rmspe:0.26581
# [120]	train-rmse:0.31506	train-rmspe:0.28812	eval-rmse:0.31214	eval-rmspe:0.26347
# [121]	train-rmse:0.31030	train-rmspe:0.28589	eval-rmse:0.30754	eval-rmspe:0.26093
# [122]	train-rmse:0.30593	train-rmspe:0.28394	eval-rmse:0.30347	eval-rmspe:0.25878
# [123]	train-rmse:0.30175	train-rmspe:0.28215	eval-rmse:0.29940	eval-rmspe:0.25665
# [124]	train-rmse:0.29791	train-rmspe:0.28054	eval-rmse:0.29586	eval-rmspe:0.25489
# [125]	train-rmse:0.29427	train-rmspe:0.27901	eval-rmse:0.29255	eval-rmspe:0.25336
# [126]	train-rmse:0.29032	train-rmspe:0.27733	eval-rmse:0.28888	eval-rmspe:0.25141
# [127]	train-rmse:0.28669	train-rmspe:0.27583	eval-rmse:0.28546	eval-rmspe:0.24967
# [128]	train-rmse:0.28323	train-rmspe:0.27449	eval-rmse:0.28235	eval-rmspe:0.24817
# [129]	train-rmse:0.27992	train-rmspe:0.27313	eval-rmse:0.27924	eval-rmspe:0.24663
# [130]	train-rmse:0.27685	train-rmspe:0.27176	eval-rmse:0.27653	eval-rmspe:0.24550
# [131]	train-rmse:0.27356	train-rmspe:0.27040	eval-rmse:0.27343	eval-rmspe:0.24391
# [132]	train-rmse:0.27034	train-rmspe:0.26900	eval-rmse:0.27045	eval-rmspe:0.24240
# [133]	train-rmse:0.26733	train-rmspe:0.26774	eval-rmse:0.26771	eval-rmspe:0.24099
# [134]	train-rmse:0.26479	train-rmspe:0.26691	eval-rmse:0.26526	eval-rmspe:0.24003
# [135]	train-rmse:0.26245	train-rmspe:0.26622	eval-rmse:0.26312	eval-rmspe:0.23926
# [136]	train-rmse:0.25969	train-rmspe:0.26506	eval-rmse:0.26050	eval-rmspe:0.23777
# [137]	train-rmse:0.25762	train-rmspe:0.26449	eval-rmse:0.25874	eval-rmspe:0.23728
# [138]	train-rmse:0.25563	train-rmspe:0.26368	eval-rmse:0.25708	eval-rmspe:0.23692
# [139]	train-rmse:0.25338	train-rmspe:0.26274	eval-rmse:0.25501	eval-rmspe:0.23602
# [140]	train-rmse:0.25070	train-rmspe:0.26147	eval-rmse:0.25264	eval-rmspe:0.23479
# [141]	train-rmse:0.24902	train-rmspe:0.26111	eval-rmse:0.25127	eval-rmspe:0.23451
# [142]	train-rmse:0.24691	train-rmspe:0.26040	eval-rmse:0.24932	eval-rmspe:0.23356
# [143]	train-rmse:0.24498	train-rmspe:0.25974	eval-rmse:0.24758	eval-rmspe:0.23289
# [144]	train-rmse:0.24253	train-rmspe:0.25863	eval-rmse:0.24553	eval-rmspe:0.23180
# [145]	train-rmse:0.24076	train-rmspe:0.25803	eval-rmse:0.24390	eval-rmspe:0.23109
# [146]	train-rmse:0.23927	train-rmspe:0.25773	eval-rmse:0.24258	eval-rmspe:0.23073
# [147]	train-rmse:0.23750	train-rmspe:0.25714	eval-rmse:0.24096	eval-rmspe:0.23000
# [148]	train-rmse:0.23618	train-rmspe:0.25691	eval-rmse:0.23980	eval-rmspe:0.22983
# [149]	train-rmse:0.23505	train-rmspe:0.25684	eval-rmse:0.23879	eval-rmspe:0.22977
# [150]	train-rmse:0.23377	train-rmspe:0.25660	eval-rmse:0.23766	eval-rmspe:0.22945
# [151]	train-rmse:0.23224	train-rmspe:0.25613	eval-rmse:0.23630	eval-rmspe:0.22883
# [152]	train-rmse:0.23103	train-rmspe:0.25593	eval-rmse:0.23520	eval-rmspe:0.22859
# [153]	train-rmse:0.22986	train-rmspe:0.25578	eval-rmse:0.23423	eval-rmspe:0.22836
# [154]	train-rmse:0.22873	train-rmspe:0.25560	eval-rmse:0.23322	eval-rmspe:0.22810
# [155]	train-rmse:0.22766	train-rmspe:0.25544	eval-rmse:0.23230	eval-rmspe:0.22788
# [156]	train-rmse:0.22548	train-rmspe:0.25419	eval-rmse:0.23026	eval-rmspe:0.22646
# [157]	train-rmse:0.22441	train-rmspe:0.25386	eval-rmse:0.22942	eval-rmspe:0.22639
# [158]	train-rmse:0.22356	train-rmspe:0.25371	eval-rmse:0.22877	eval-rmspe:0.22660
# [159]	train-rmse:0.22256	train-rmspe:0.25360	eval-rmse:0.22791	eval-rmspe:0.22640
# [160]	train-rmse:0.22182	train-rmspe:0.25358	eval-rmse:0.22722	eval-rmspe:0.22646
# [161]	train-rmse:0.22048	train-rmspe:0.25302	eval-rmse:0.22601	eval-rmspe:0.22583
# [162]	train-rmse:0.21981	train-rmspe:0.25307	eval-rmse:0.22548	eval-rmspe:0.22588
# [163]	train-rmse:0.21860	train-rmspe:0.25263	eval-rmse:0.22441	eval-rmspe:0.22531
# [164]	train-rmse:0.21775	train-rmspe:0.25235	eval-rmse:0.22377	eval-rmspe:0.22517
# [165]	train-rmse:0.21678	train-rmspe:0.25215	eval-rmse:0.22288	eval-rmspe:0.22484
# [166]	train-rmse:0.21604	train-rmspe:0.25212	eval-rmse:0.22225	eval-rmspe:0.22476
# [167]	train-rmse:0.21427	train-rmspe:0.25104	eval-rmse:0.22064	eval-rmspe:0.22358
# [168]	train-rmse:0.21364	train-rmspe:0.25091	eval-rmse:0.22011	eval-rmspe:0.22345
# [169]	train-rmse:0.21313	train-rmspe:0.25095	eval-rmse:0.21964	eval-rmspe:0.22350
# [170]	train-rmse:0.21153	train-rmspe:0.25006	eval-rmse:0.21826	eval-rmspe:0.22251
# [171]	train-rmse:0.21094	train-rmspe:0.25002	eval-rmse:0.21778	eval-rmspe:0.22245
# [172]	train-rmse:0.20969	train-rmspe:0.24937	eval-rmse:0.21684	eval-rmspe:0.22190
# [173]	train-rmse:0.20903	train-rmspe:0.24925	eval-rmse:0.21634	eval-rmspe:0.22182
# [174]	train-rmse:0.20820	train-rmspe:0.24892	eval-rmse:0.21564	eval-rmspe:0.22146
# [175]	train-rmse:0.20759	train-rmspe:0.24879	eval-rmse:0.21520	eval-rmspe:0.22140
# [176]	train-rmse:0.20695	train-rmspe:0.24865	eval-rmse:0.21457	eval-rmspe:0.22119
# [177]	train-rmse:0.20597	train-rmspe:0.24802	eval-rmse:0.21374	eval-rmspe:0.22058
# [178]	train-rmse:0.20505	train-rmspe:0.24636	eval-rmse:0.21248	eval-rmspe:0.21961
# [179]	train-rmse:0.20435	train-rmspe:0.24609	eval-rmse:0.21177	eval-rmspe:0.21921
# [180]	train-rmse:0.20391	train-rmspe:0.24608	eval-rmse:0.21133	eval-rmspe:0.21919
# [181]	train-rmse:0.20366	train-rmspe:0.24625	eval-rmse:0.21111	eval-rmspe:0.21935
# [182]	train-rmse:0.20277	train-rmspe:0.24565	eval-rmse:0.21036	eval-rmspe:0.21879
# [183]	train-rmse:0.20227	train-rmspe:0.24552	eval-rmse:0.20999	eval-rmspe:0.21869
# [184]	train-rmse:0.20191	train-rmspe:0.24552	eval-rmse:0.20966	eval-rmspe:0.21871
# [185]	train-rmse:0.20156	train-rmspe:0.24546	eval-rmse:0.20937	eval-rmspe:0.21873
# [186]	train-rmse:0.20137	train-rmspe:0.24565	eval-rmse:0.20925	eval-rmspe:0.21889
# [187]	train-rmse:0.20005	train-rmspe:0.24476	eval-rmse:0.20799	eval-rmspe:0.21778
# [188]	train-rmse:0.19977	train-rmspe:0.24474	eval-rmse:0.20785	eval-rmspe:0.21790
# [189]	train-rmse:0.19961	train-rmspe:0.24492	eval-rmse:0.20775	eval-rmspe:0.21806
# [190]	train-rmse:0.19900	train-rmspe:0.24462	eval-rmse:0.20725	eval-rmspe:0.21772
# [191]	train-rmse:0.19821	train-rmspe:0.24415	eval-rmse:0.20666	eval-rmspe:0.21738
# [192]	train-rmse:0.19774	train-rmspe:0.24396	eval-rmse:0.20639	eval-rmspe:0.21722
# [193]	train-rmse:0.19698	train-rmspe:0.24350	eval-rmse:0.20582	eval-rmspe:0.21689
# [194]	train-rmse:0.19626	train-rmspe:0.24305	eval-rmse:0.20527	eval-rmspe:0.21651
# [195]	train-rmse:0.19574	train-rmspe:0.24280	eval-rmse:0.20484	eval-rmspe:0.21620
# [196]	train-rmse:0.19520	train-rmspe:0.24251	eval-rmse:0.20439	eval-rmspe:0.21585
# [197]	train-rmse:0.19486	train-rmspe:0.24229	eval-rmse:0.20415	eval-rmspe:0.21585
# [198]	train-rmse:0.19458	train-rmspe:0.24219	eval-rmse:0.20405	eval-rmspe:0.21590
# [199]	train-rmse:0.19436	train-rmspe:0.24221	eval-rmse:0.20394	eval-rmspe:0.21592
# [200]	train-rmse:0.19401	train-rmspe:0.24210	eval-rmse:0.20364	eval-rmspe:0.21576
# [201]	train-rmse:0.19375	train-rmspe:0.24194	eval-rmse:0.20341	eval-rmspe:0.21566
# [202]	train-rmse:0.19311	train-rmspe:0.24155	eval-rmse:0.20295	eval-rmspe:0.21540
# [203]	train-rmse:0.19253	train-rmspe:0.24131	eval-rmse:0.20247	eval-rmspe:0.21508
# [204]	train-rmse:0.19233	train-rmspe:0.24126	eval-rmse:0.20234	eval-rmspe:0.21511
# [205]	train-rmse:0.19154	train-rmspe:0.24056	eval-rmse:0.20167	eval-rmspe:0.21449
# [206]	train-rmse:0.19116	train-rmspe:0.24050	eval-rmse:0.20128	eval-rmspe:0.21422
# [207]	train-rmse:0.19025	train-rmspe:0.23979	eval-rmse:0.20049	eval-rmspe:0.21354
# [208]	train-rmse:0.18999	train-rmspe:0.23968	eval-rmse:0.20031	eval-rmspe:0.21347
# [209]	train-rmse:0.18982	train-rmspe:0.23963	eval-rmse:0.20013	eval-rmspe:0.21346
# [210]	train-rmse:0.18937	train-rmspe:0.23955	eval-rmse:0.19978	eval-rmspe:0.21324
# [211]	train-rmse:0.18873	train-rmspe:0.23910	eval-rmse:0.19920	eval-rmspe:0.21277
# [212]	train-rmse:0.18837	train-rmspe:0.23892	eval-rmse:0.19890	eval-rmspe:0.21257
# [213]	train-rmse:0.18798	train-rmspe:0.23869	eval-rmse:0.19856	eval-rmspe:0.21230
# [214]	train-rmse:0.18754	train-rmspe:0.23844	eval-rmse:0.19818	eval-rmspe:0.21196
# [215]	train-rmse:0.18705	train-rmspe:0.23813	eval-rmse:0.19772	eval-rmspe:0.21154
# [216]	train-rmse:0.18666	train-rmspe:0.23791	eval-rmse:0.19740	eval-rmspe:0.21128
# [217]	train-rmse:0.18593	train-rmspe:0.23724	eval-rmse:0.19676	eval-rmspe:0.21058
# [218]	train-rmse:0.18553	train-rmspe:0.23689	eval-rmse:0.19647	eval-rmspe:0.21041
# [219]	train-rmse:0.18510	train-rmspe:0.23662	eval-rmse:0.19608	eval-rmspe:0.21008
# [220]	train-rmse:0.18468	train-rmspe:0.23635	eval-rmse:0.19571	eval-rmspe:0.20975
# [221]	train-rmse:0.18420	train-rmspe:0.23604	eval-rmse:0.19528	eval-rmspe:0.20935
# [222]	train-rmse:0.18383	train-rmspe:0.23575	eval-rmse:0.19504	eval-rmspe:0.20918
# [223]	train-rmse:0.18377	train-rmspe:0.23582	eval-rmse:0.19501	eval-rmspe:0.20923
# [224]	train-rmse:0.18355	train-rmspe:0.23572	eval-rmse:0.19480	eval-rmspe:0.20911
# [225]	train-rmse:0.18316	train-rmspe:0.23549	eval-rmse:0.19442	eval-rmspe:0.20878
# [226]	train-rmse:0.18287	train-rmspe:0.23530	eval-rmse:0.19413	eval-rmspe:0.20854
# [227]	train-rmse:0.18245	train-rmspe:0.23501	eval-rmse:0.19374	eval-rmspe:0.20820
# [228]	train-rmse:0.18185	train-rmspe:0.23450	eval-rmse:0.19327	eval-rmspe:0.20777
# [229]	train-rmse:0.18144	train-rmspe:0.23342	eval-rmse:0.19291	eval-rmspe:0.20749
# [230]	train-rmse:0.18104	train-rmspe:0.23315	eval-rmse:0.19254	eval-rmspe:0.20716
# [231]	train-rmse:0.18062	train-rmspe:0.23284	eval-rmse:0.19219	eval-rmspe:0.20684
# [232]	train-rmse:0.18037	train-rmspe:0.23267	eval-rmse:0.19198	eval-rmspe:0.20667
# [233]	train-rmse:0.18020	train-rmspe:0.23266	eval-rmse:0.19187	eval-rmspe:0.20657
# [234]	train-rmse:0.17998	train-rmspe:0.23195	eval-rmse:0.19170	eval-rmspe:0.20644
# [235]	train-rmse:0.17952	train-rmspe:0.23151	eval-rmse:0.19132	eval-rmspe:0.20605
# [236]	train-rmse:0.17928	train-rmspe:0.23132	eval-rmse:0.19112	eval-rmspe:0.20587
# [237]	train-rmse:0.17905	train-rmspe:0.23115	eval-rmse:0.19096	eval-rmspe:0.20572
# [238]	train-rmse:0.17877	train-rmspe:0.23097	eval-rmse:0.19069	eval-rmspe:0.20551
# [239]	train-rmse:0.17830	train-rmspe:0.23066	eval-rmse:0.19025	eval-rmspe:0.20508
# [240]	train-rmse:0.17771	train-rmspe:0.22858	eval-rmse:0.18973	eval-rmspe:0.20450
# [241]	train-rmse:0.17722	train-rmspe:0.22822	eval-rmse:0.18927	eval-rmspe:0.20402
# [242]	train-rmse:0.17666	train-rmspe:0.22774	eval-rmse:0.18876	eval-rmspe:0.20353
# [243]	train-rmse:0.17631	train-rmspe:0.22712	eval-rmse:0.18848	eval-rmspe:0.20329
# [244]	train-rmse:0.17540	train-rmspe:0.22628	eval-rmse:0.18773	eval-rmspe:0.20250
# [245]	train-rmse:0.17460	train-rmspe:0.22554	eval-rmse:0.18707	eval-rmspe:0.20185
# [246]	train-rmse:0.17428	train-rmspe:0.22521	eval-rmse:0.18680	eval-rmspe:0.20154
# [247]	train-rmse:0.17380	train-rmspe:0.22482	eval-rmse:0.18639	eval-rmspe:0.20119
# [248]	train-rmse:0.17364	train-rmspe:0.22471	eval-rmse:0.18631	eval-rmspe:0.20112
# [249]	train-rmse:0.17342	train-rmspe:0.22452	eval-rmse:0.18602	eval-rmspe:0.20086
# [250]	train-rmse:0.17311	train-rmspe:0.22426	eval-rmse:0.18574	eval-rmspe:0.20060
# [251]	train-rmse:0.17263	train-rmspe:0.22249	eval-rmse:0.18531	eval-rmspe:0.20014
# [252]	train-rmse:0.17233	train-rmspe:0.21985	eval-rmse:0.18488	eval-rmspe:0.19974
# [253]	train-rmse:0.17217	train-rmspe:0.21974	eval-rmse:0.18479	eval-rmspe:0.19970
# [254]	train-rmse:0.17203	train-rmspe:0.21958	eval-rmse:0.18482	eval-rmspe:0.19987
# [255]	train-rmse:0.17155	train-rmspe:0.21915	eval-rmse:0.18442	eval-rmspe:0.19949
# [256]	train-rmse:0.17135	train-rmspe:0.21900	eval-rmse:0.18426	eval-rmspe:0.19934
# [257]	train-rmse:0.17087	train-rmspe:0.21863	eval-rmse:0.18380	eval-rmspe:0.19886
# [258]	train-rmse:0.17050	train-rmspe:0.21834	eval-rmse:0.18347	eval-rmspe:0.19851
# [259]	train-rmse:0.16997	train-rmspe:0.21579	eval-rmse:0.18303	eval-rmspe:0.19810
# [260]	train-rmse:0.16966	train-rmspe:0.21549	eval-rmse:0.18277	eval-rmspe:0.19785
# [261]	train-rmse:0.16914	train-rmspe:0.21507	eval-rmse:0.18235	eval-rmspe:0.19744
# [262]	train-rmse:0.16861	train-rmspe:0.21459	eval-rmse:0.18191	eval-rmspe:0.19699
# [263]	train-rmse:0.16817	train-rmspe:0.21419	eval-rmse:0.18157	eval-rmspe:0.19663
# [264]	train-rmse:0.16785	train-rmspe:0.21389	eval-rmse:0.18134	eval-rmspe:0.19641
# [265]	train-rmse:0.16769	train-rmspe:0.21376	eval-rmse:0.18120	eval-rmspe:0.19631
# [266]	train-rmse:0.16734	train-rmspe:0.21348	eval-rmse:0.18087	eval-rmspe:0.19594
# [267]	train-rmse:0.16704	train-rmspe:0.21294	eval-rmse:0.18065	eval-rmspe:0.19574
# [268]	train-rmse:0.16679	train-rmspe:0.21271	eval-rmse:0.18048	eval-rmspe:0.19559
# [269]	train-rmse:0.16654	train-rmspe:0.21249	eval-rmse:0.18025	eval-rmspe:0.19535
# [270]	train-rmse:0.16590	train-rmspe:0.21165	eval-rmse:0.17969	eval-rmspe:0.19468
# [271]	train-rmse:0.16560	train-rmspe:0.21141	eval-rmse:0.17940	eval-rmspe:0.19437
# [272]	train-rmse:0.16534	train-rmspe:0.21114	eval-rmse:0.17915	eval-rmspe:0.19410
# [273]	train-rmse:0.16506	train-rmspe:0.21089	eval-rmse:0.17890	eval-rmspe:0.19385
# [274]	train-rmse:0.16479	train-rmspe:0.21062	eval-rmse:0.17868	eval-rmspe:0.19363
# [275]	train-rmse:0.16426	train-rmspe:0.21015	eval-rmse:0.17825	eval-rmspe:0.19317
# [276]	train-rmse:0.16401	train-rmspe:0.20996	eval-rmse:0.17799	eval-rmspe:0.19289
# [277]	train-rmse:0.16361	train-rmspe:0.20953	eval-rmse:0.17767	eval-rmspe:0.19247
# [278]	train-rmse:0.16304	train-rmspe:0.20900	eval-rmse:0.17722	eval-rmspe:0.19198
# [279]	train-rmse:0.16260	train-rmspe:0.20851	eval-rmse:0.17682	eval-rmspe:0.19149
# [280]	train-rmse:0.16198	train-rmspe:0.20795	eval-rmse:0.17630	eval-rmspe:0.19095
# [281]	train-rmse:0.16152	train-rmspe:0.20757	eval-rmse:0.17591	eval-rmspe:0.19052
# [282]	train-rmse:0.16128	train-rmspe:0.20736	eval-rmse:0.17574	eval-rmspe:0.19039
# [283]	train-rmse:0.16107	train-rmspe:0.20659	eval-rmse:0.17560	eval-rmspe:0.19025
# [284]	train-rmse:0.16083	train-rmspe:0.20640	eval-rmse:0.17536	eval-rmspe:0.19001
# [285]	train-rmse:0.16073	train-rmspe:0.20501	eval-rmse:0.17527	eval-rmspe:0.18990
# [286]	train-rmse:0.16054	train-rmspe:0.20475	eval-rmse:0.17511	eval-rmspe:0.18967
# [287]	train-rmse:0.16034	train-rmspe:0.20454	eval-rmse:0.17509	eval-rmspe:0.18975
# [288]	train-rmse:0.15993	train-rmspe:0.20240	eval-rmse:0.17477	eval-rmspe:0.18943
# [289]	train-rmse:0.15983	train-rmspe:0.20228	eval-rmse:0.17469	eval-rmspe:0.18934
# [290]	train-rmse:0.15933	train-rmspe:0.20184	eval-rmse:0.17419	eval-rmspe:0.18879
# [291]	train-rmse:0.15910	train-rmspe:0.20153	eval-rmse:0.17399	eval-rmspe:0.18854
# [292]	train-rmse:0.15893	train-rmspe:0.20107	eval-rmse:0.17391	eval-rmspe:0.18847
# [293]	train-rmse:0.15882	train-rmspe:0.20102	eval-rmse:0.17387	eval-rmspe:0.18848
# [294]	train-rmse:0.15839	train-rmspe:0.20067	eval-rmse:0.17347	eval-rmspe:0.18804
# [295]	train-rmse:0.15819	train-rmspe:0.20049	eval-rmse:0.17331	eval-rmspe:0.18792
# [296]	train-rmse:0.15795	train-rmspe:0.20014	eval-rmse:0.17310	eval-rmspe:0.18771
# [297]	train-rmse:0.15774	train-rmspe:0.19993	eval-rmse:0.17294	eval-rmspe:0.18753
# [298]	train-rmse:0.15704	train-rmspe:0.19925	eval-rmse:0.17234	eval-rmspe:0.18685
# [299]	train-rmse:0.15679	train-rmspe:0.19896	eval-rmse:0.17210	eval-rmspe:0.18661
# [300]	train-rmse:0.15666	train-rmspe:0.19771	eval-rmse:0.17200	eval-rmspe:0.18651
# [301]	train-rmse:0.15654	train-rmspe:0.19756	eval-rmse:0.17200	eval-rmspe:0.18650
# [302]	train-rmse:0.15593	train-rmspe:0.19700	eval-rmse:0.17149	eval-rmspe:0.18596
# [303]	train-rmse:0.15531	train-rmspe:0.19639	eval-rmse:0.17097	eval-rmspe:0.18536
# [304]	train-rmse:0.15522	train-rmspe:0.19531	eval-rmse:0.17089	eval-rmspe:0.18528
# [305]	train-rmse:0.15479	train-rmspe:0.19496	eval-rmse:0.17053	eval-rmspe:0.18492
# [306]	train-rmse:0.15449	train-rmspe:0.19465	eval-rmse:0.17028	eval-rmspe:0.18460
# [307]	train-rmse:0.15439	train-rmspe:0.19368	eval-rmse:0.17020	eval-rmspe:0.18453
# [308]	train-rmse:0.15423	train-rmspe:0.19352	eval-rmse:0.17023	eval-rmspe:0.18463
# [309]	train-rmse:0.15394	train-rmspe:0.19329	eval-rmse:0.16997	eval-rmspe:0.18433
# [310]	train-rmse:0.15370	train-rmspe:0.19307	eval-rmse:0.16981	eval-rmspe:0.18416
# [311]	train-rmse:0.15358	train-rmspe:0.19297	eval-rmse:0.16972	eval-rmspe:0.18401
# [312]	train-rmse:0.15333	train-rmspe:0.19158	eval-rmse:0.16955	eval-rmspe:0.18382
# [313]	train-rmse:0.15324	train-rmspe:0.19072	eval-rmse:0.16947	eval-rmspe:0.18374
# [314]	train-rmse:0.15301	train-rmspe:0.19045	eval-rmse:0.16929	eval-rmspe:0.18355
# [315]	train-rmse:0.15243	train-rmspe:0.18988	eval-rmse:0.16881	eval-rmspe:0.18300
# [316]	train-rmse:0.15186	train-rmspe:0.18930	eval-rmse:0.16832	eval-rmspe:0.18247
# [317]	train-rmse:0.15144	train-rmspe:0.18893	eval-rmse:0.16794	eval-rmspe:0.18208
# [318]	train-rmse:0.15127	train-rmspe:0.18876	eval-rmse:0.16779	eval-rmspe:0.18194
# [319]	train-rmse:0.15117	train-rmspe:0.18867	eval-rmse:0.16778	eval-rmspe:0.18199
# [320]	train-rmse:0.15049	train-rmspe:0.18802	eval-rmse:0.16719	eval-rmspe:0.18127
# [321]	train-rmse:0.15037	train-rmspe:0.18790	eval-rmse:0.16709	eval-rmspe:0.18116
# [322]	train-rmse:0.15022	train-rmspe:0.18770	eval-rmse:0.16699	eval-rmspe:0.18104
# [323]	train-rmse:0.15000	train-rmspe:0.18752	eval-rmse:0.16681	eval-rmspe:0.18085
# [324]	train-rmse:0.14951	train-rmspe:0.18704	eval-rmse:0.16637	eval-rmspe:0.18038
# [325]	train-rmse:0.14909	train-rmspe:0.18668	eval-rmse:0.16596	eval-rmspe:0.17993
# [326]	train-rmse:0.14866	train-rmspe:0.18629	eval-rmse:0.16559	eval-rmspe:0.17954
# [327]	train-rmse:0.14819	train-rmspe:0.18576	eval-rmse:0.16520	eval-rmspe:0.17910
# [328]	train-rmse:0.14784	train-rmspe:0.18544	eval-rmse:0.16495	eval-rmspe:0.17884
# [329]	train-rmse:0.14766	train-rmspe:0.18526	eval-rmse:0.16484	eval-rmspe:0.17874
# [330]	train-rmse:0.14758	train-rmspe:0.18448	eval-rmse:0.16478	eval-rmspe:0.17866
# [331]	train-rmse:0.14715	train-rmspe:0.18408	eval-rmse:0.16443	eval-rmspe:0.17829
# [332]	train-rmse:0.14705	train-rmspe:0.18359	eval-rmse:0.16434	eval-rmspe:0.17820
# [333]	train-rmse:0.14684	train-rmspe:0.18231	eval-rmse:0.16419	eval-rmspe:0.17803
# [334]	train-rmse:0.14636	train-rmspe:0.18183	eval-rmse:0.16379	eval-rmspe:0.17758
# [335]	train-rmse:0.14616	train-rmspe:0.18165	eval-rmse:0.16359	eval-rmspe:0.17736
# [336]	train-rmse:0.14586	train-rmspe:0.18138	eval-rmse:0.16330	eval-rmspe:0.17699
# [337]	train-rmse:0.14576	train-rmspe:0.18130	eval-rmse:0.16323	eval-rmspe:0.17695
# [338]	train-rmse:0.14554	train-rmspe:0.18121	eval-rmse:0.16306	eval-rmspe:0.17678
# [339]	train-rmse:0.14512	train-rmspe:0.18084	eval-rmse:0.16270	eval-rmspe:0.17641
# [340]	train-rmse:0.14492	train-rmspe:0.18068	eval-rmse:0.16252	eval-rmspe:0.17621
# [341]	train-rmse:0.14477	train-rmspe:0.18053	eval-rmse:0.16237	eval-rmspe:0.17605
# [342]	train-rmse:0.14462	train-rmspe:0.18035	eval-rmse:0.16224	eval-rmspe:0.17592
# [343]	train-rmse:0.14450	train-rmspe:0.18025	eval-rmse:0.16215	eval-rmspe:0.17581
# [344]	train-rmse:0.14397	train-rmspe:0.17973	eval-rmse:0.16168	eval-rmspe:0.17527
# [345]	train-rmse:0.14350	train-rmspe:0.17930	eval-rmse:0.16128	eval-rmspe:0.17485
# [346]	train-rmse:0.14341	train-rmspe:0.17863	eval-rmse:0.16120	eval-rmspe:0.17477
# [347]	train-rmse:0.14308	train-rmspe:0.17835	eval-rmse:0.16089	eval-rmspe:0.17441
# [348]	train-rmse:0.14284	train-rmspe:0.17754	eval-rmse:0.16072	eval-rmspe:0.17421
# [349]	train-rmse:0.14263	train-rmspe:0.17735	eval-rmse:0.16053	eval-rmspe:0.17402
# [350]	train-rmse:0.14228	train-rmspe:0.17704	eval-rmse:0.16020	eval-rmspe:0.17364
# [351]	train-rmse:0.14220	train-rmspe:0.17667	eval-rmse:0.16014	eval-rmspe:0.17357
# [352]	train-rmse:0.14209	train-rmspe:0.17657	eval-rmse:0.16013	eval-rmspe:0.17363
# [353]	train-rmse:0.14202	train-rmspe:0.17652	eval-rmse:0.16007	eval-rmspe:0.17356
# [354]	train-rmse:0.14153	train-rmspe:0.17608	eval-rmse:0.15957	eval-rmspe:0.17297
# [355]	train-rmse:0.14089	train-rmspe:0.17541	eval-rmse:0.15904	eval-rmspe:0.17233
# [356]	train-rmse:0.14076	train-rmspe:0.17528	eval-rmse:0.15893	eval-rmspe:0.17222
# [357]	train-rmse:0.14063	train-rmspe:0.17515	eval-rmse:0.15881	eval-rmspe:0.17210
# [358]	train-rmse:0.14055	train-rmspe:0.17465	eval-rmse:0.15874	eval-rmspe:0.17203
# [359]	train-rmse:0.14008	train-rmspe:0.17421	eval-rmse:0.15834	eval-rmspe:0.17158
# [360]	train-rmse:0.13998	train-rmspe:0.17407	eval-rmse:0.15827	eval-rmspe:0.17155
# [361]	train-rmse:0.13984	train-rmspe:0.17394	eval-rmse:0.15817	eval-rmspe:0.17143
# [362]	train-rmse:0.13970	train-rmspe:0.17381	eval-rmse:0.15805	eval-rmspe:0.17131
# [363]	train-rmse:0.13949	train-rmspe:0.17361	eval-rmse:0.15786	eval-rmspe:0.17110
# [364]	train-rmse:0.13916	train-rmspe:0.17334	eval-rmse:0.15756	eval-rmspe:0.17079
# [365]	train-rmse:0.13909	train-rmspe:0.17325	eval-rmse:0.15751	eval-rmspe:0.17073
# [366]	train-rmse:0.13870	train-rmspe:0.17290	eval-rmse:0.15711	eval-rmspe:0.17026
# [367]	train-rmse:0.13851	train-rmspe:0.17272	eval-rmse:0.15688	eval-rmspe:0.17001
# [368]	train-rmse:0.13818	train-rmspe:0.17234	eval-rmse:0.15661	eval-rmspe:0.16966
# [369]	train-rmse:0.13786	train-rmspe:0.17198	eval-rmse:0.15638	eval-rmspe:0.16939
# [370]	train-rmse:0.13748	train-rmspe:0.17159	eval-rmse:0.15608	eval-rmspe:0.16900
# [371]	train-rmse:0.13734	train-rmspe:0.17140	eval-rmse:0.15594	eval-rmspe:0.16882
# [372]	train-rmse:0.13728	train-rmspe:0.17136	eval-rmse:0.15588	eval-rmspe:0.16876
# [373]	train-rmse:0.13697	train-rmspe:0.17108	eval-rmse:0.15563	eval-rmspe:0.16848
# [374]	train-rmse:0.13685	train-rmspe:0.17096	eval-rmse:0.15554	eval-rmspe:0.16838
# [375]	train-rmse:0.13679	train-rmspe:0.17091	eval-rmse:0.15549	eval-rmspe:0.16833
# [376]	train-rmse:0.13639	train-rmspe:0.17056	eval-rmse:0.15513	eval-rmspe:0.16798
# [377]	train-rmse:0.13601	train-rmspe:0.17024	eval-rmse:0.15475	eval-rmspe:0.16757
# [378]	train-rmse:0.13583	train-rmspe:0.16994	eval-rmse:0.15460	eval-rmspe:0.16740
# [379]	train-rmse:0.13563	train-rmspe:0.16975	eval-rmse:0.15445	eval-rmspe:0.16725
# [380]	train-rmse:0.13521	train-rmspe:0.16937	eval-rmse:0.15410	eval-rmspe:0.16685
# [381]	train-rmse:0.13507	train-rmspe:0.16919	eval-rmse:0.15403	eval-rmspe:0.16685
# [382]	train-rmse:0.13500	train-rmspe:0.16913	eval-rmse:0.15398	eval-rmspe:0.16679
# [383]	train-rmse:0.13486	train-rmspe:0.16899	eval-rmse:0.15386	eval-rmspe:0.16666
# [384]	train-rmse:0.13461	train-rmspe:0.16876	eval-rmse:0.15366	eval-rmspe:0.16646
# [385]	train-rmse:0.13455	train-rmspe:0.16870	eval-rmse:0.15361	eval-rmspe:0.16641
# [386]	train-rmse:0.13445	train-rmspe:0.16863	eval-rmse:0.15357	eval-rmspe:0.16634
# [387]	train-rmse:0.13432	train-rmspe:0.16848	eval-rmse:0.15343	eval-rmspe:0.16617
# [388]	train-rmse:0.13425	train-rmspe:0.16832	eval-rmse:0.15338	eval-rmspe:0.16611
# [389]	train-rmse:0.13397	train-rmspe:0.16807	eval-rmse:0.15292	eval-rmspe:0.16559
# [390]	train-rmse:0.13363	train-rmspe:0.16775	eval-rmse:0.15264	eval-rmspe:0.16525
# [391]	train-rmse:0.13332	train-rmspe:0.16741	eval-rmse:0.15240	eval-rmspe:0.16495
# [392]	train-rmse:0.13301	train-rmspe:0.16709	eval-rmse:0.15215	eval-rmspe:0.16466
# [393]	train-rmse:0.13265	train-rmspe:0.16676	eval-rmse:0.15186	eval-rmspe:0.16437
# [394]	train-rmse:0.13239	train-rmspe:0.16654	eval-rmse:0.15162	eval-rmspe:0.16415
# [395]	train-rmse:0.13213	train-rmspe:0.16633	eval-rmse:0.15126	eval-rmspe:0.16376
# [396]	train-rmse:0.13190	train-rmspe:0.16612	eval-rmse:0.15104	eval-rmspe:0.16356
# [397]	train-rmse:0.13179	train-rmspe:0.16603	eval-rmse:0.15095	eval-rmspe:0.16346
# [398]	train-rmse:0.13164	train-rmspe:0.16587	eval-rmse:0.15086	eval-rmspe:0.16335
# [399]	train-rmse:0.13159	train-rmspe:0.16568	eval-rmse:0.15082	eval-rmspe:0.16331
# [400]	train-rmse:0.13140	train-rmspe:0.16550	eval-rmse:0.15069	eval-rmspe:0.16320
# [401]	train-rmse:0.13135	train-rmspe:0.16546	eval-rmse:0.15078	eval-rmspe:0.16337
# [402]	train-rmse:0.13099	train-rmspe:0.16513	eval-rmse:0.15051	eval-rmspe:0.16309
# [403]	train-rmse:0.13056	train-rmspe:0.16473	eval-rmse:0.15016	eval-rmspe:0.16267
# [404]	train-rmse:0.13047	train-rmspe:0.16463	eval-rmse:0.15010	eval-rmspe:0.16260
# [405]	train-rmse:0.13027	train-rmspe:0.16443	eval-rmse:0.14993	eval-rmspe:0.16243
# [406]	train-rmse:0.13008	train-rmspe:0.16426	eval-rmse:0.14981	eval-rmspe:0.16233
# [407]	train-rmse:0.12986	train-rmspe:0.16403	eval-rmse:0.14961	eval-rmspe:0.16204
# [408]	train-rmse:0.12976	train-rmspe:0.16392	eval-rmse:0.14957	eval-rmspe:0.16204
# [409]	train-rmse:0.12957	train-rmspe:0.16375	eval-rmse:0.14942	eval-rmspe:0.16186
# [410]	train-rmse:0.12950	train-rmspe:0.16364	eval-rmse:0.14937	eval-rmspe:0.16183
# [411]	train-rmse:0.12927	train-rmspe:0.16344	eval-rmse:0.14920	eval-rmspe:0.16162
# [412]	train-rmse:0.12903	train-rmspe:0.16322	eval-rmse:0.14897	eval-rmspe:0.16137
# [413]	train-rmse:0.12888	train-rmspe:0.16261	eval-rmse:0.14884	eval-rmspe:0.16122
# [414]	train-rmse:0.12877	train-rmspe:0.16250	eval-rmse:0.14874	eval-rmspe:0.16111
# [415]	train-rmse:0.12849	train-rmspe:0.16227	eval-rmse:0.14849	eval-rmspe:0.16085
# [416]	train-rmse:0.12833	train-rmspe:0.16222	eval-rmse:0.14836	eval-rmspe:0.16071
# [417]	train-rmse:0.12801	train-rmspe:0.16192	eval-rmse:0.14807	eval-rmspe:0.16039
# [418]	train-rmse:0.12789	train-rmspe:0.16176	eval-rmse:0.14797	eval-rmspe:0.16029
# [419]	train-rmse:0.12780	train-rmspe:0.16163	eval-rmse:0.14791	eval-rmspe:0.16023
# [420]	train-rmse:0.12773	train-rmspe:0.16142	eval-rmse:0.14789	eval-rmspe:0.16022
# [421]	train-rmse:0.12769	train-rmspe:0.16138	eval-rmse:0.14786	eval-rmspe:0.16018
# [422]	train-rmse:0.12757	train-rmspe:0.16128	eval-rmse:0.14773	eval-rmspe:0.16004
# [423]	train-rmse:0.12728	train-rmspe:0.16102	eval-rmse:0.14748	eval-rmspe:0.15975
# [424]	train-rmse:0.12721	train-rmspe:0.16091	eval-rmse:0.14749	eval-rmspe:0.15977
# [425]	train-rmse:0.12704	train-rmspe:0.16015	eval-rmse:0.14736	eval-rmspe:0.15964
# [426]	train-rmse:0.12693	train-rmspe:0.16002	eval-rmse:0.14727	eval-rmspe:0.15955
# [427]	train-rmse:0.12686	train-rmspe:0.15996	eval-rmse:0.14722	eval-rmspe:0.15949
# [428]	train-rmse:0.12671	train-rmspe:0.15982	eval-rmse:0.14711	eval-rmspe:0.15938
# [429]	train-rmse:0.12650	train-rmspe:0.15960	eval-rmse:0.14696	eval-rmspe:0.15920
# [430]	train-rmse:0.12615	train-rmspe:0.15929	eval-rmse:0.14667	eval-rmspe:0.15889
# [431]	train-rmse:0.12609	train-rmspe:0.15921	eval-rmse:0.14673	eval-rmspe:0.15902
# [432]	train-rmse:0.12596	train-rmspe:0.15901	eval-rmse:0.14663	eval-rmspe:0.15890
# [433]	train-rmse:0.12578	train-rmspe:0.15883	eval-rmse:0.14645	eval-rmspe:0.15871
# [434]	train-rmse:0.12570	train-rmspe:0.15873	eval-rmse:0.14647	eval-rmspe:0.15874
# [435]	train-rmse:0.12550	train-rmspe:0.15852	eval-rmse:0.14631	eval-rmspe:0.15857
# [436]	train-rmse:0.12535	train-rmspe:0.15839	eval-rmse:0.14619	eval-rmspe:0.15845
# [437]	train-rmse:0.12526	train-rmspe:0.15829	eval-rmse:0.14611	eval-rmspe:0.15837
# [438]	train-rmse:0.12522	train-rmspe:0.15824	eval-rmse:0.14613	eval-rmspe:0.15842
# [439]	train-rmse:0.12510	train-rmspe:0.15815	eval-rmse:0.14604	eval-rmspe:0.15831
# [440]	train-rmse:0.12498	train-rmspe:0.15804	eval-rmse:0.14595	eval-rmspe:0.15821
# [441]	train-rmse:0.12473	train-rmspe:0.15781	eval-rmse:0.14575	eval-rmspe:0.15800
# [442]	train-rmse:0.12466	train-rmspe:0.15770	eval-rmse:0.14575	eval-rmspe:0.15803
# [443]	train-rmse:0.12440	train-rmspe:0.15748	eval-rmse:0.14554	eval-rmspe:0.15779
# [444]	train-rmse:0.12419	train-rmspe:0.15727	eval-rmse:0.14535	eval-rmspe:0.15758
# [445]	train-rmse:0.12395	train-rmspe:0.15707	eval-rmse:0.14517	eval-rmspe:0.15739
# [446]	train-rmse:0.12383	train-rmspe:0.15696	eval-rmse:0.14506	eval-rmspe:0.15727
# [447]	train-rmse:0.12377	train-rmspe:0.15652	eval-rmse:0.14502	eval-rmspe:0.15723
# [448]	train-rmse:0.12364	train-rmspe:0.15640	eval-rmse:0.14493	eval-rmspe:0.15711
# [449]	train-rmse:0.12344	train-rmspe:0.15622	eval-rmse:0.14476	eval-rmspe:0.15692
# [450]	train-rmse:0.12331	train-rmspe:0.15609	eval-rmse:0.14466	eval-rmspe:0.15681
# [451]	train-rmse:0.12324	train-rmspe:0.15599	eval-rmse:0.14463	eval-rmspe:0.15679
# [452]	train-rmse:0.12308	train-rmspe:0.15586	eval-rmse:0.14449	eval-rmspe:0.15661
# [453]	train-rmse:0.12297	train-rmspe:0.15575	eval-rmse:0.14440	eval-rmspe:0.15650
# [454]	train-rmse:0.12288	train-rmspe:0.15568	eval-rmse:0.14433	eval-rmspe:0.15642
# [455]	train-rmse:0.12277	train-rmspe:0.15558	eval-rmse:0.14412	eval-rmspe:0.15620
# [456]	train-rmse:0.12269	train-rmspe:0.15551	eval-rmse:0.14405	eval-rmspe:0.15613
# [457]	train-rmse:0.12258	train-rmspe:0.15541	eval-rmse:0.14396	eval-rmspe:0.15604
# [458]	train-rmse:0.12253	train-rmspe:0.15526	eval-rmse:0.14396	eval-rmspe:0.15606
# [459]	train-rmse:0.12223	train-rmspe:0.15497	eval-rmse:0.14370	eval-rmspe:0.15573
# [460]	train-rmse:0.12198	train-rmspe:0.15471	eval-rmse:0.14349	eval-rmspe:0.15548
# [461]	train-rmse:0.12191	train-rmspe:0.15431	eval-rmse:0.14344	eval-rmspe:0.15542
# [462]	train-rmse:0.12160	train-rmspe:0.15401	eval-rmse:0.14319	eval-rmspe:0.15513
# [463]	train-rmse:0.12141	train-rmspe:0.15383	eval-rmse:0.14303	eval-rmspe:0.15496
# [464]	train-rmse:0.12128	train-rmspe:0.15371	eval-rmse:0.14291	eval-rmspe:0.15481
# [465]	train-rmse:0.12122	train-rmspe:0.15359	eval-rmse:0.14286	eval-rmspe:0.15476
# [466]	train-rmse:0.12115	train-rmspe:0.15352	eval-rmse:0.14281	eval-rmspe:0.15471
# [467]	train-rmse:0.12088	train-rmspe:0.15327	eval-rmse:0.14260	eval-rmspe:0.15448
# [468]	train-rmse:0.12073	train-rmspe:0.15314	eval-rmse:0.14246	eval-rmspe:0.15432
# [469]	train-rmse:0.12064	train-rmspe:0.15304	eval-rmse:0.14244	eval-rmspe:0.15431
# [470]	train-rmse:0.12054	train-rmspe:0.15294	eval-rmse:0.14237	eval-rmspe:0.15423
# [471]	train-rmse:0.12020	train-rmspe:0.15262	eval-rmse:0.14210	eval-rmspe:0.15393
# [472]	train-rmse:0.12017	train-rmspe:0.15250	eval-rmse:0.14208	eval-rmspe:0.15390
# [473]	train-rmse:0.12014	train-rmspe:0.15246	eval-rmse:0.14203	eval-rmspe:0.15382
# [474]	train-rmse:0.12004	train-rmspe:0.15235	eval-rmse:0.14190	eval-rmspe:0.15365
# [475]	train-rmse:0.11986	train-rmspe:0.15209	eval-rmse:0.14175	eval-rmspe:0.15349
# [476]	train-rmse:0.11982	train-rmspe:0.15176	eval-rmse:0.14172	eval-rmspe:0.15345
# [477]	train-rmse:0.11972	train-rmspe:0.15167	eval-rmse:0.14164	eval-rmspe:0.15335
# [478]	train-rmse:0.11945	train-rmspe:0.15142	eval-rmse:0.14142	eval-rmspe:0.15309
# [479]	train-rmse:0.11930	train-rmspe:0.15129	eval-rmse:0.14131	eval-rmspe:0.15297
# [480]	train-rmse:0.11916	train-rmspe:0.15116	eval-rmse:0.14120	eval-rmspe:0.15285
# [481]	train-rmse:0.11898	train-rmspe:0.15098	eval-rmse:0.14106	eval-rmspe:0.15268
# [482]	train-rmse:0.11891	train-rmspe:0.15092	eval-rmse:0.14102	eval-rmspe:0.15263
# [483]	train-rmse:0.11886	train-rmspe:0.15067	eval-rmse:0.14099	eval-rmspe:0.15262
# [484]	train-rmse:0.11879	train-rmspe:0.15060	eval-rmse:0.14093	eval-rmspe:0.15256
# [485]	train-rmse:0.11872	train-rmspe:0.15062	eval-rmse:0.14087	eval-rmspe:0.15248
# [486]	train-rmse:0.11859	train-rmspe:0.15050	eval-rmse:0.14075	eval-rmspe:0.15233
# [487]	train-rmse:0.11848	train-rmspe:0.15041	eval-rmse:0.14065	eval-rmspe:0.15222
# [488]	train-rmse:0.11835	train-rmspe:0.15027	eval-rmse:0.14054	eval-rmspe:0.15210
# [489]	train-rmse:0.11830	train-rmspe:0.15025	eval-rmse:0.14049	eval-rmspe:0.15206
# [490]	train-rmse:0.11824	train-rmspe:0.15019	eval-rmse:0.14044	eval-rmspe:0.15200
# [491]	train-rmse:0.11815	train-rmspe:0.15011	eval-rmse:0.14037	eval-rmspe:0.15192
# [492]	train-rmse:0.11800	train-rmspe:0.14998	eval-rmse:0.14026	eval-rmspe:0.15178
# [493]	train-rmse:0.11788	train-rmspe:0.14987	eval-rmse:0.14015	eval-rmspe:0.15167
# [494]	train-rmse:0.11783	train-rmspe:0.14979	eval-rmse:0.13997	eval-rmspe:0.15144
# [495]	train-rmse:0.11774	train-rmspe:0.14970	eval-rmse:0.13989	eval-rmspe:0.15136
# [496]	train-rmse:0.11764	train-rmspe:0.14950	eval-rmse:0.13981	eval-rmspe:0.15126
# [497]	train-rmse:0.11749	train-rmspe:0.14937	eval-rmse:0.13969	eval-rmspe:0.15113
# [498]	train-rmse:0.11744	train-rmspe:0.14932	eval-rmse:0.13964	eval-rmspe:0.15107
# [499]	train-rmse:0.11732	train-rmspe:0.14922	eval-rmse:0.13956	eval-rmspe:0.15099

# %%
# validation
y_pred = model.predict(xgb.DMatrix(x_valid))
error = rmspe(np.expm1(y_valid), np.expm1(y_pred))
print('RMSPE: {:.4f}'.format(error))
# Out:
# RMSPE: 0.1510

# %%
# rmspe correction on the whole
def correction():
    weights = np.arange(0.98, 1.02, 0.005)
    errors = []
    for w in weights:
        error = rmspe(np.expm1(y_valid), np.expm1(y_pred*w))
        errors.append(error)
        
    # make line plot
    plt.plot(weights, errors)
    plt.xlabel('weight')
    plt.ylabel('RMSPE')
    plt.title('RMSPE Curve')
    # print min error
    idx = errors.index(min(errors))
    print('Best weight is {}, RMSPE is {:.4f}'.format(weights[idx], min(errors)))
    
correction()
# Out:
# Best weight is 0.995, RMSPE is 0.1431

# %%
dtrain = xgb.DMatrix(x_train_total, y_train_total)
dtest = xgb.DMatrix(x_test)
# specify parameters via map
params = {"objective": "reg:linear", # for linear regression
          "booster" : "gbtree",   # use tree based models 
          "eta": 0.03,   # learning rate
          "max_depth": 10,    # maximum depth of a tree
          "subsample": 0.9,    # Subsample ratio of the training instances
          "colsample_bytree": 0.7,   # Subsample ratio of columns when constructing each tree
          "silent": 1,   # silent mode
          "seed": 10   # Random number seed
          }
num_round = 500
model = xgb.train(params, dtrain, num_round)
# make prediction
preds = model.predict(dtest)
# Out:
# [19:13:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:13:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
# make submission using best weight
result = pd.DataFrame({"Id": test["Id"],'Sales': np.expm1(preds*0.995)})
result.to_csv("../data/submission_xgb.csv", index=False)

# plot feature importance, show top 10 features
fig, ax = plt.subplots(figsize=(8,8))
xgb.plot_importance(model, max_num_features= 10, height=0.5, ax=ax)
plt.show()
